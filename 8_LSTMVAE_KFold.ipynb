# %%
# from _future_ import absolute_import, division, print_function
# %load_ext autoreload
# %autoreload 2

import sys, os
script_dir  = os.path.normpath(os.path.abspath("."))
root_dir    = os.path.normpath(os.path.abspath(script_dir + "/../../../.."))
source_dir  = os.path.normpath(os.path.abspath(script_dir + "/../.."))
if source_dir in sys.path: sys.path.remove(source_dir)
sys.path.insert(1, source_dir)

import warnings
warnings.filterwarnings("ignore")

# %%
from common import *

# %%
dp = DataPath()

# %%
load_path  = f'{dp.output_path}/seq_norm_8_nots'
train_path = f'{dp.output_path}/seq_norm_8_nots/train_VAE_Kfold'
if os.path.exists(train_path) == False: os.makedirs(train_path)

# %%
data_info = dict(np.load(f'{load_path}/data_info.npz'))

# %%
load_info = joblib.load(f'{load_path}/save_info.joblib')
df_data   = pd.read_hdf(f'{load_path}/df_data.hdf')
scaler = joblib.load(f'{load_path}/scaler.joblib')

# %%
from sklearn.model_selection import StratifiedKFold
import numpy as np
import os
import random
import torch
import sys
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
from tqdm import tqdm
from sklearn.metrics import log_loss
from sklearn.metrics import roc_auc_score

import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Param

# %%
# params
seed = 42
num_folds = 5
scoring = "roc_auc"
batch_size = 1028

def seed_everything(seed_value):
    random.seed(seed_value)
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)
    os.environ['PYTHONHASHSEED'] = str(seed_value)

    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

    tf.random.set_seed(seed)

seed_everything(seed)

# %% [markdown]
# # Load Data

# %%
x_train = data_info["x"]
y_train = data_info["seq_y"]
y_onehot = np.zeros((len(data_info["seq_y"]),2), dtype=np.float32)
for idx in range(len(y_train)):
    y_onehot[idx, y_train[idx]] = 1.0

print(f'x: {x_train.shape}')
print(f'y: {y_train.shape}')
print(f'y_onehot: {y_onehot.shape}')
# Out:
# x: (298701, 8, 25)
# y: (298701,)
# y_onehot: (298701, 2)

# %% [markdown]
# # Metrics

# %%
#Loss
from tensorflow.keras import backend as K

smooth  = 1.
epsilon = 1e-7

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
# dice_coef

def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# dice_coef_loss
def dice_coef_multi(y_true, y_pred):
    y_true_f = K.flatten(y_true[..., 1:])
    y_pred_f = K.flatten(y_pred[..., 1:])

    y_true_sum = K.sum(K.cast(y_true_f > epsilon, dtype="float32"))
    y_pred_sum = K.sum(y_pred_f)

    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (y_true_sum + y_pred_sum + smooth)
# dice_coef_multi

def dice_coef_multi_loss(y_true, y_pred):
    return 1.0 - dice_coef_multi(y_true, y_pred)
# dice_coef_multi_loss

def mean_acc(y_true, y_pred):
    y_true_label = K.argmax(y_true, axis = 1)
    y_pred_label = K.argmax(y_pred, axis = 1)
    cm = tf.math.confusion_matrix(y_true_label, y_pred_label)
    cm_norm = cm / tf.reshape(tf.reduce_sum(cm, axis = 1), (-1, 1))
    zero_pos = tf.where(tf.math.is_nan(cm_norm))
    n_zero   = tf.shape(zero_pos)[0]
    cm_norm  = tf.tensor_scatter_nd_update(cm_norm, zero_pos, tf.zeros(n_zero, dtype=tf.double))
    mean_acc_val = tf.reduce_mean(tf.linalg.diag_part(cm_norm))
#   print(y_true.shape)
#     if tf.math.is_nan(mean_acc_val) == True:
#         print("Is Nan")
#         print(y_true_label.numpy())
#         print(y_pred_label.numpy())
#         print(cm_norm.numpy())
    return mean_acc_val

# %%
metrics = ["acc", dice_coef_multi, mean_acc, tf.keras.metrics.AUC()]
loss_fn = ["categorical_crossentropy", dice_coef_multi_loss] # "categorical_crossentropy",
optimizer_fn = tf.keras.optimizers.Adam(learning_rate=0.0001)
weights = None

# %% [markdown]
# # Model

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
#Create a sampling layer

class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
#TVAE
from sklearn.metrics import roc_auc_score, precision_recall_curve, auc, roc_curve

tf.keras.backend.clear_session()


def build_VAE(input_shape, latent_dim):
    #Encoder
    encoder_inputs = keras.Input(shape=input_shape)
    x = layers.LSTM(100, activation='tanh', return_sequences=True)(encoder_inputs)
    x = layers.LSTM(50, activation='tanh', return_sequences=True)(x)
    x = layers.LSTM(25,activation='tanh')(x)

    z_mean = layers.Dense(latent_dim, name="z_mean")(x)
    z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
    z = Sampling()([z_mean, z_log_var])

    # Clf decoder
    decoder1 = layers.Dense(8, activation='relu')(z)
    decoder1 = layers.Dropout(0.2)(decoder1)

    decoder1 = layers.Dense(64, activation='relu')(decoder1)
    decoder1 = layers.Dropout(0.2)(decoder1)

    decoder1 = layers.Dense(32, activation='relu')(decoder1)
    decoder1 = layers.Dropout(0.2)(decoder1)

    decoder1 = layers.Dense(16, activation='relu')(decoder1)
    decoder1 = layers.Dropout(0.1)(decoder1)

    decoder_out = layers.Dense(2, activation='sigmoid')(decoder1)
    VAE_clf = tf.keras.Model(inputs=encoder_inputs, outputs=decoder_out)

    VAE_clf.compile(
            optimizer = optimizer_fn,
            loss      = loss_fn,
            metrics   = metrics,
            run_eagerly = True,
        )
    
    return VAE_clf
    #model.compile(
    #optimizer='adam',
    #loss='categorical_crossentropy',
    #metrics='accuracy',
    #
    
VAE_clf = build_VAE(input_shape = x_train.shape[1:], latent_dim = 8)
VAE_clf.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 8, 25)]      0           []
#
#  lstm (LSTM)                    (None, 8, 100)       50400       ['input_1[0][0]']
#
#  lstm_1 (LSTM)                  (None, 8, 50)        30200       ['lstm[0][0]']
#
#  lstm_2 (LSTM)                  (None, 25)           7600        ['lstm_1[0][0]']
#
#  z_mean (Dense)                 (None, 8)            208         ['lstm_2[0][0]']
#
#  z_log_var (Dense)              (None, 8)            208         ['lstm_2[0][0]']
#
#  sampling (Sampling)            (None, 8)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
#  dense (Dense)                  (None, 8)            72          ['sampling[0][0]']
#
#  dropout (Dropout)              (None, 8)            0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 64)           576         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 32)           0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 16)           528         ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 16)           0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 2)            34          ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 91,906
# Trainable params: 91,906
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x_train.shape
# Out:
# (298701, 8, 25)

# %%
tf.keras.backend.clear_session()

#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import roc_auc_score, precision_recall_curve, auc, roc_curve, average_precision_score

kf = KFold(n_splits=5, random_state=seed, shuffle=True)
stra_kf = StratifiedKFold(n_splits=5, random_state=seed, shuffle=True)

result_info = {}
count = 0
#date  = time().time()
for train_index, test_index in kf.split(x_train, y_train):
    #tf.keras.backend.clear_session()
    x_train1, x_test1 = x_train[train_index], x_train[test_index]
    y_train1, y_test1 = y_train[train_index], y_train[test_index]

    y_train_onehot1 = y_onehot[train_index]
    y_test_onehot1 = y_onehot[test_index]

    rs_path = f'{train_path}/rs'
    if os.path.exists(rs_path) == False: os.makedirs(rs_path)
    
    #logs_path = f'{train_path}/logs_ECG/Fold_{count}'
    logs_path = f'{train_path}/logs_VAE_Fold_{count}'
    if os.path.exists(logs_path) == False: os.makedirs(logs_path)
    print(count)
    
    best_model_path = f'{train_path}/model_VAE_KFold_{count}.hdf5'
    log_model_path  = f'{train_path}/model_VAE_KFold_{count}.logs.csv'
    print(best_model_path)
    
    if os.path.exists(best_model_path):
        print(f'Remove {best_model_path}')
        os.remove(best_model_path)
        # !ls "$logs_path"
    
    if os.path.exists(log_model_path):
        print(f'Remove {log_model_path}')
        os.remove(log_model_path)
        # !ls "$logs_path"
    

    cbs = []
    cbs.append(tf.keras.callbacks.ModelCheckpoint(
        filepath=best_model_path,
        save_weights_only=True,
        monitor='loss',
        mode='min',
        #monitor='val_acc',
        #mode='max',
    # monitor='val_mean_acc',
    # mode='max',
        verbose=1,
        save_best_only=True))

    cbs.append(tf.keras.callbacks.TensorBoard(log_dir=f'{logs_path}'))
    cbs.append(tf.keras.callbacks.EarlyStopping(monitor = 'loss', mode='min', patience=10))
    cbs.append(tf.keras.callbacks.CSVLogger(filename=log_model_path, separator=",", append=False))
    
    model = build_VAE(input_shape = x_train.shape[1:], latent_dim = 8)

    model.fit(
            x_train1,
            y_train_onehot1,
            epochs=1000,
            batch_size=1024*2,
            #validation_split = 0.2,
            #validation_data=(x_test1, y_test_onehot1),
            shuffle=True,
            #verbose=2,
            callbacks=cbs,
            #class_weight = class_weight
        )
    
    
    model.load_weights(best_model_path)
                   
    # predict test-fold
    y1_test_pred_score = model.predict(x_test1)
    y1_test_pred_label = np.argmax(y1_test_pred_score, axis = 1)

    y1_test_cm_norm = confusion_matrix(y_test1, y1_test_pred_label, normalize='true')
    y1_test_cm      = confusion_matrix(y_test1, y1_test_pred_label)

    fpr, tpr, thr = roc_curve(y_test1, y1_test_pred_label, pos_label=1)
    y1_auc = "%.5f" % auc(fpr, tpr)
    y1_auc_prob = roc_auc_score(y_test1, y1_test_pred_score[:,1])

    precision, recall, _ = precision_recall_curve(y_test1, y1_test_pred_label)
    y1_prc = "%.5f" % auc(precision, recall)
    avg_pre = average_precision_score(y_test1, y1_test_pred_label, pos_label=1)

    

    print(f'TestFold {count} Mean-Acc: {np.mean(y1_test_cm_norm.diagonal())}\n{y1_test_cm}\n')
    print(f'TestFold {count} Mean-Auc: {y1_auc}')
    print(f'TestFold {count} AUC proba: {y1_auc_prob}')
    print(f'TestFold {count} Mean-PRC: {y1_prc}')
    print(f'TestFold {count} AVG-PRC: {avg_pre}')
    
    res_VAE_VS = {
    "true" : y_test1,
    "predict" : y1_test_pred_label,
    "score_0" : y1_test_pred_score[:,0],
    "score_1" : y1_test_pred_score[:,1],
    "AUC" : y1_auc,
    "AUC_prob" : y1_auc_prob,
    "PRC" : y1_prc,
    "avg_PRC" : avg_pre
    }

    res_VAE_VS = pd.DataFrame(res_VAE_VS)
    
    res_VAE_VS.to_csv(f'{rs_path}/res_VAE_Fold_{count}.csv')
    
    #if os.path.exists(rs_path) == True:
     #   print(f'Remove {rs_path}')
      #  os.remove(rs_path)
       # !ls "$rs_path"
    
    tf.keras.backend.clear_session()
    
    count +=1
    #break
    pass
# Out:
# 0
# /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# Remove /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# train
# Remove /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.logs.csv
# train
# Epoch 1/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.1161 - acc: 0.9857 - dice_coef_multi: 0.0378 - mean_acc: 0.4988 - auc: 0.9983
# Epoch 00001: loss improved from inf to 0.11612, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s 165ms/step - loss: 0.1161 - acc: 0.9857 - dice_coef_multi: 0.0378 - mean_acc: 0.4988 - auc: 0.9983
# Epoch 2/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0210 - acc: 0.9966 - dice_coef_multi: 0.0708 - mean_acc: 0.5000 - auc: 0.9991
# Epoch 00002: loss improved from 0.11612 to 0.02099, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 21s 183ms/step - loss: 0.0210 - acc: 0.9966 - dice_coef_multi: 0.0708 - mean_acc: 0.5000 - auc: 0.9991
# Epoch 3/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0168 - acc: 0.9966 - dice_coef_multi: 0.0965 - mean_acc: 0.5000 - auc: 0.9994
# Epoch 00003: loss improved from 0.02099 to 0.01679, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 22s 189ms/step - loss: 0.0168 - acc: 0.9966 - dice_coef_multi: 0.0965 - mean_acc: 0.5000 - auc: 0.9994
# Epoch 4/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0150 - acc: 0.9966 - dice_coef_multi: 0.1128 - mean_acc: 0.5050 - auc: 0.9995
# Epoch 00004: loss improved from 0.01679 to 0.01505, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 23s 194ms/step - loss: 0.0150 - acc: 0.9966 - dice_coef_multi: 0.1128 - mean_acc: 0.5050 - auc: 0.9995
# Epoch 5/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0139 - acc: 0.9967 - dice_coef_multi: 0.1251 - mean_acc: 0.5000 - auc: 0.9996
# Epoch 00005: loss improved from 0.01505 to 0.01393, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 22s 189ms/step - loss: 0.0139 - acc: 0.9967 - dice_coef_multi: 0.1251 - mean_acc: 0.5000 - auc: 0.9996
# Epoch 6/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0125 - acc: 0.9967 - dice_coef_multi: 0.1444 - mean_acc: 0.5000 - auc: 0.9997
# Epoch 00006: loss improved from 0.01393 to 0.01246, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s 166ms/step - loss: 0.0125 - acc: 0.9967 - dice_coef_multi: 0.1444 - mean_acc: 0.5000 - auc: 0.9997
# Epoch 7/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0117 - acc: 0.9967 - dice_coef_multi: 0.1613 - mean_acc: 0.5000 - auc: 0.9997
# Epoch 00007: loss improved from 0.01246 to 0.01166, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s 165ms/step - loss: 0.0117 - acc: 0.9967 - dice_coef_multi: 0.1613 - mean_acc: 0.5000 - auc: 0.9997
# Epoch 8/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0113 - acc: 0.9967 - dice_coef_multi: 0.1793 - mean_acc: 0.5000 - auc: 0.9997
# Epoch 00008: loss improved from 0.01166 to 0.01126, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s 164ms/step - loss: 0.0113 - acc: 0.9967 - dice_coef_multi: 0.1793 - mean_acc: 0.5000 - auc: 0.9997
# Epoch 9/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0105 - acc: 0.9967 - dice_coef_multi: 0.1929 - mean_acc: 0.5000 - auc: 0.9998
# Epoch 00009: loss improved from 0.01126 to 0.01051, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s 166ms/step - loss: 0.0105 - acc: 0.9967 - dice_coef_multi: 0.1929 - mean_acc: 0.5000 - auc: 0.9998
# Epoch 10/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0102 - acc: 0.9967 - dice_coef_multi: 0.2059 - mean_acc: 0.5000 - auc: 0.9998
# Epoch 00010: loss improved from 0.01051 to 0.01022, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s
1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0063 - acc: 0.9969 - dice_coef_multi: 0.3609 - mean_acc: 0.5482 - auc: 0.9999
# Epoch 00023: loss improved from 0.00640 to 0.00634, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s 159ms/step - loss: 0.0063 - acc: 0.9969 - dice_coef_multi: 0.3609 - mean_acc: 0.5482 - auc: 0.9999
# Epoch 24/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0060 - acc: 0.9971 - dice_coef_multi: 0.3609 - mean_acc: 0.5754 - auc: 0.9999
# Epoch 00024: loss improved from 0.00634 to 0.00605, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s 161ms/step - loss: 0.0060 - acc: 0.9971 - dice_coef_multi: 0.3609 - mean_acc: 0.5754 - auc: 0.9999
# Epoch 25/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0061 - acc: 0.9974 - dice_coef_multi: 0.3790 - mean_acc: 0.6243 - auc: 0.9999
# Epoch 00025: loss did not improve from 0.00605
# 117/117 [==============================] - 19s 158ms/step - loss: 0.0061 - acc: 0.9974 - dice_coef_multi: 0.3790 - mean_acc: 0.6243 - auc: 0.9999
# Epoch 26/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0059 - acc: 0.9975 - dice_coef_multi: 0.3815 - mean_acc: 0.6551 - auc: 0.9999
# Epoch 00026: loss improved from 0.00605 to 0.00594, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s 159ms/step - loss: 0.0059 - acc: 0.9975 - dice_coef_multi: 0.3815 - mean_acc: 0.6551 - auc: 0.9999
# Epoch 27/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0056 - acc: 0.9977 - dice_coef_multi: 0.3886 - mean_acc: 0.7009 - auc: 0.9999
# Epoch 00027: loss improved from 0.00594 to 0.00558, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s 161ms/step - loss: 0.0056 - acc: 0.9977 - dice_coef_multi: 0.3886 - mean_acc: 0.7009 - auc: 0.9999
# Epoch 28/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0055 - acc: 0.9978 - dice_coef_multi: 0.4038 - mean_acc: 0.7209 - auc: 0.9999
# Epoch 00028: loss improved from 0.00558 to 0.00551, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 18s 154ms/step - loss: 0.0055 - acc: 0.9978 - dice_coef_multi: 0.4038 - mean_acc: 0.7209 - auc: 0.9999
# Epoch 29/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0056 - acc: 0.9979 - dice_coef_multi: 0.4021 - mean_acc: 0.7254 - auc: 0.9999
# Epoch 00029: loss did not improve from 0.00551
# 117/117 [==============================] - 19s 163ms/step - loss: 0.0056 - acc: 0.9979 - dice_coef_multi: 0.4021 - mean_acc: 0.7254 - auc: 0.9999
# Epoch 30/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0054 - acc: 0.9980 - dice_coef_multi: 0.4102 - mean_acc: 0.7632 - auc: 0.9999
# Epoch 00030: loss improved from 0.00551 to 0.00537, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 18s 158ms/step - loss: 0.0054 - acc: 0.9980 - dice_coef_multi: 0.4102 - mean_acc: 0.7632 - auc: 0.9999
# Epoch 31/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0051 - acc: 0.9981 - dice_coef_multi: 0.4347 - mean_acc: 0.7751 - auc: 0.9999
# Epoch 00031: loss improved from 0.00537 to 0.00513, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s 163ms/step - loss: 0.0051 - acc: 0.9981 - dice_coef_multi: 0.4347 - mean_acc: 0.7751 - auc: 0.9999
# Epoch 32/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0052 - acc: 0.9982 - dice_coef_multi: 0.4531 - mean_acc: 0.8079 - auc: 0.9999
# Epoch 00032: loss did not improve from 0.00513
# 117/117 [==============================] - 19s 163ms/step - loss: 0.0052 - acc: 0.9982 - dice_coef_multi: 0.4531 - mean_acc: 0.8079 - auc: 0.9999
# Epoch 33/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0048 - acc: 0.9983 - dice_coef_multi: 0.4661 - mean_acc: 0.8168 - auc: 0.9999
# Epoch 00033: loss improved from 0.00513 to 0.00484, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s 159ms/step - loss: 0.0048 - acc: 0.9983 - dice_coef_multi: 0.4661 - mean_acc: 0.8168 - auc: 0.9999
# Epoch 34/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0047 - acc: 0.9984 - dice_coef_multi: 0.4855 - mean_acc: 0.8275 - auc: 0.9999
# Epoch 00034: loss improved from 0.00484 to 0.00466, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 18s 158ms/step - loss: 0.0047 - acc: 0.9984 - dice_coef_multi: 0.4855 - mean_acc: 0.8275 - auc: 0.9999
# Epoch 35/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0047 - acc: 0.9983 - dice_coef_multi: 0.4943 - mean_acc: 0.8262 - auc: 0.9999
# Epoch 00035: loss did not improve from 0.00466
# 117/117 [==============================] - 18s 151ms/step - loss: 0.0047 - acc: 0.9983 - dice_coef_multi: 0.4943 - mean_acc: 0.8262 - auc: 0.9999
# Epoch 36/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0043 - acc: 0.9986 - dice_coef_multi: 0.5174 - mean_acc: 0.8576 - auc: 0.9999
# Epoch 00036: loss improved from 0.00466 to 0.00434, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 18s 156ms/step - loss: 0.0043 - acc: 0.9986 - dice_coef_multi: 0.5174 - mean_acc: 0.8576 - auc: 0.9999
# Epoch 37/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0043 - acc: 0.9986 - dice_coef_multi: 0.5174 - mean_acc: 0.8771 - auc: 0.9999
# Epoch 00037: loss improved from 0.00434 to 0.00426, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s 164ms/step - loss: 0.0043 - acc: 0.9986 - dice_coef_multi: 0.5174 - mean_acc: 0.8771 - auc: 0.9999
# Epoch 38/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0043 - acc: 0.9986 - dice_coef_multi: 0.5320 - mean_acc: 0.8789 - auc: 0.9999
# Epoch 00038: loss did not improve from 0.00426
# 117/117 [==============================] - 18s 156ms/step - loss: 0.0043 - acc: 0.9986 - dice_coef_multi: 0.5320 - mean_acc: 0.8789 - auc: 0.9999
# Epoch 39/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0043 - acc: 0.9987 - dice_coef_multi: 0.5211 - mean_acc: 0.8787 - auc: 0.9999
# Epoch 00039: loss did not improve from 0.00426
# 117/117 [==============================] - 18s 156ms/step - loss: 0.0043 - acc: 0.9987 - dice_coef_multi: 0.5211 - mean_acc: 0.8787 - auc: 0.9999
# Epoch 40/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0041 - acc: 0.9987 - dice_coef_multi: 0.5358 - mean_acc: 0.8847 - auc: 0.9999
# Epoch 00040: loss improved from 0.00426 to 0.00409, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 18s 156ms/step - loss: 0.0041 - acc: 0.9987 - dice_coef_multi: 0.5358 - mean_acc: 0.8847 - auc: 0.9999
# Epoch 41/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0038 - acc: 0.9988 - dice_coef_multi: 0.5598 - mean_acc: 0.8931 - auc: 0.9999
# Epoch 00041: loss improved from 0.00409 to 0.00383, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s 159ms/step - loss: 0.0038 - acc: 0.9988 - dice_coef_multi: 0.5598 - mean_acc: 0.8931 - auc: 0.9999
# Epoch 42/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0039 - acc: 0.9988 - dice_coef_multi: 0.5542 - mean_acc: 0.8902 - auc: 0.9999
# Epoch 00042: loss did not improve from 0.00383
# 117/117 [==============================] - 18s 157ms/step - loss: 0.0039 - acc: 0.9988 - dice_coef_multi: 0.5542 - mean_acc: 0.8902 - auc: 0.9999
# Epoch 43/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0037 - acc: 0.9989 - dice_coef_multi: 0.5727 - mean_acc: 0.9090 - auc: 0.9999
# Epoch 00043: loss improved from 0.00383 to 0.00369, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s 160ms/step - loss: 0.0037 - acc: 0.9989 - dice_coef_multi: 0.5727 - mean_acc: 0.9090 - auc: 0.9999
# Epoch 44/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0038 - acc: 0.9988 - dice_coef_multi: 0.5885 - mean_acc: 0.9059 - auc: 0.9999
# Epoch 00044: loss did not improve from 0.00369
# 117/117 [==============================] - 18s 157ms/step - loss: 0.0038 - acc: 0.9988 - dice_coef_multi: 0.5885 - mean_acc: 0.9059 - auc: 0.9999
# Epoch 45/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0037 - acc: 0.9989 - dice_coef_multi: 0.5778 - mean_acc: 0.9031 - auc: 0.9999
# Epoch 00045: loss did not improve from 0.00369
# 117/117 [==============================] - 18s 156ms/step - loss: 0.0037 - acc: 0.9989 - dice_coef_multi: 0.5778 - mean_acc: 0.9031 - auc: 0.9999
# Epoch 46/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0035 - acc: 0.9989 - dice_coef_multi: 0.5940 - mean_acc: 0.9092 - auc: 1.0000
# Epoch 00046: loss improved from 0.00369 to 0.00349, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 18s 157ms/step - loss: 0.0035 - acc: 0.9989 - dice_coef_multi: 0.5940 - mean_acc: 0.9092 - auc: 1.0000
# Epoch 47/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0034 - acc: 0.9989 - dice_coef_multi: 0.6149 - mean_acc: 0.9127 - auc: 1.0000
# Epoch 00047: loss improved from 0.00349 to 0.00340, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s 161ms/step - loss: 0.0034 - acc: 0.9989 - dice_coef_multi: 0.6149 - mean_acc: 0.9127 - auc: 1.0000
# Epoch 48/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0034 - acc: 0.9989 - dice_coef_multi: 0.6130 - mean_acc: 0.9108 - auc: 1.0000
# Epoch 00048: loss did not improve from 0.00340
# 117/117 [==============================] - 18s 157ms/step - loss: 0.0034 - acc: 0.9989 - dice_coef_multi: 0.6130 - mean_acc: 0.9108 - auc: 1.0000
# Epoch 49/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0035 - acc: 0.9990 - dice_coef_multi: 0.6245 - mean_acc: 0.9133 - auc: 0.9999
# Epoch 00049: loss did not improve from 0.00340
# 117/117 [==============================] - 19s 159ms/step - loss: 0.0035 - acc: 0.9990 - dice_coef_multi: 0.6245 - mean_acc: 0.9133 - auc: 0.9999
# Epoch 50/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0034 - acc: 0.9989 - dice_coef_multi: 0.6188 - mean_acc: 0.9138 - auc: 0.9999
# Epoch 00050: loss improved from 0.00340 to 0.00337, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 18s 152ms/step - loss: 0.0034 - acc: 0.9989 - dice_coef_multi: 0.6188 - mean_acc: 0.9138 - auc: 0.9999
# Epoch 51/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0033 - acc: 0.9990 - dice_coef_multi: 0.6284 - mean_acc: 0.9031 - auc: 1.0000
# Epoch 00051: loss improved from 0.00337 to 0.00326, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 18s 156ms/step - loss: 0.0033 - acc: 0.9990 - dice_coef_multi: 0.6284 - mean_acc: 0.9031 - auc: 1.0000
# Epoch 52/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0031 - acc: 0.9990 - dice_coef_multi: 0.6418 - mean_acc: 0.9146 - auc: 1.0000
# Epoch 00052: loss improved from 0.00326 to 0.00307, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 18s 154ms/step - loss: 0.0031 - acc: 0.9990 - dice_coef_multi: 0.6418 - mean_acc: 0.9146 - auc: 1.0000
# Epoch 53/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0031 - acc: 0.9991 - dice_coef_multi: 0.6606 - mean_acc: 0.9169 - auc: 1.0000
# Epoch 00053: loss improved from 0.00307 to 0.00306, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s 162ms/step - loss: 0.0031 - acc: 0.9991 - dice_coef_multi: 0.6606 - mean_acc: 0.9169 - auc: 1.0000
# Epoch 54/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0030 - acc: 0.9990 - dice_coef_multi: 0.6471 - mean_acc: 0.9068 - auc: 1.0000
# Epoch 00054: loss improved from 0.00306 to 0.00301, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 19s
1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0024 - acc: 0.9991 - dice_coef_multi: 0.7196 - mean_acc: 0.9156 - auc: 1.0000
# Epoch 00065: loss improved from 0.00247 to 0.00242, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 17s 146ms/step - loss: 0.0024 - acc: 0.9991 - dice_coef_multi: 0.7196 - mean_acc: 0.9156 - auc: 1.0000
# Epoch 66/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0025 - acc: 0.9991 - dice_coef_multi: 0.7081 - mean_acc: 0.9161 - auc: 1.0000
# Epoch 00066: loss did not improve from 0.00242
# 117/117 [==============================] - 17s 147ms/step - loss: 0.0025 - acc: 0.9991 - dice_coef_multi: 0.7081 - mean_acc: 0.9161 - auc: 1.0000
# Epoch 67/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0025 - acc: 0.9991 - dice_coef_multi: 0.7147 - mean_acc: 0.9208 - auc: 1.0000
# Epoch 00067: loss did not improve from 0.00242
# 117/117 [==============================] - 17s 146ms/step - loss: 0.0025 - acc: 0.9991 - dice_coef_multi: 0.7147 - mean_acc: 0.9208 - auc: 1.0000
# Epoch 68/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0024 - acc: 0.9991 - dice_coef_multi: 0.7223 - mean_acc: 0.9168 - auc: 1.0000
# Epoch 00068: loss improved from 0.00242 to 0.00239, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 17s 146ms/step - loss: 0.0024 - acc: 0.9991 - dice_coef_multi: 0.7223 - mean_acc: 0.9168 - auc: 1.0000
# Epoch 69/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0023 - acc: 0.9991 - dice_coef_multi: 0.7205 - mean_acc: 0.9227 - auc: 1.0000
# Epoch 00069: loss improved from 0.00239 to 0.00230, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 17s 149ms/step - loss: 0.0023 - acc: 0.9991 - dice_coef_multi: 0.7205 - mean_acc: 0.9227 - auc: 1.0000
# Epoch 70/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0024 - acc: 0.9992 - dice_coef_multi: 0.7200 - mean_acc: 0.9185 - auc: 1.0000
# Epoch 00070: loss did not improve from 0.00230
# 117/117 [==============================] - 17s 145ms/step - loss: 0.0024 - acc: 0.9992 - dice_coef_multi: 0.7200 - mean_acc: 0.9185 - auc: 1.0000
# Epoch 71/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0021 - acc: 0.9993 - dice_coef_multi: 0.7275 - mean_acc: 0.9149 - auc: 1.0000
# Epoch 00071: loss improved from 0.00230 to 0.00210, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 17s 148ms/step - loss: 0.0021 - acc: 0.9993 - dice_coef_multi: 0.7275 - mean_acc: 0.9149 - auc: 1.0000
# Epoch 72/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0022 - acc: 0.9991 - dice_coef_multi: 0.7472 - mean_acc: 0.9217 - auc: 1.0000
# Epoch 00072: loss did not improve from 0.00210
# 117/117 [==============================] - 17s 144ms/step - loss: 0.0022 - acc: 0.9991 - dice_coef_multi: 0.7472 - mean_acc: 0.9217 - auc: 1.0000
# Epoch 73/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0022 - acc: 0.9991 - dice_coef_multi: 0.7443 - mean_acc: 0.9285 - auc: 1.0000
# Epoch 00073: loss did not improve from 0.00210
# 117/117 [==============================] - 17s 144ms/step - loss: 0.0022 - acc: 0.9991 - dice_coef_multi: 0.7443 - mean_acc: 0.9285 - auc: 1.0000
# Epoch 74/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0023 - acc: 0.9991 - dice_coef_multi: 0.7410 - mean_acc: 0.9225 - auc: 1.0000
# Epoch 00074: loss did not improve from 0.00210
# 117/117 [==============================] - 17s 145ms/step - loss: 0.0023 - acc: 0.9991 - dice_coef_multi: 0.7410 - mean_acc: 0.9225 - auc: 1.0000
# Epoch 75/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0022 - acc: 0.
saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 18s 150ms/step - loss: 0.0019 - acc: 0.9992 - dice_coef_multi: 0.7695 - mean_acc: 0.9253 - auc: 1.0000
# Epoch 86/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0019 - acc: 0.9993 - dice_coef_multi: 0.7870 - mean_acc: 0.9384 - auc: 1.0000
# Epoch 00086: loss improved from 0.00192 to 0.00187, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 17s 148ms/step - loss: 0.0019 - acc: 0.9993 - dice_coef_multi: 0.7870 - mean_acc: 0.9384 - auc: 1.0000
# Epoch 87/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0020 - acc: 0.9992 - dice_coef_multi: 0.7635 - mean_acc: 0.9367 - auc: 1.0000
# Epoch 00087: loss did not improve from 0.00187
# 117/117 [==============================] - 17s 149ms/step - loss: 0.0020 - acc: 0.9992 - dice_coef_multi: 0.7635 - mean_acc: 0.9367 - auc: 1.0000
# Epoch 88/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0020 - acc: 0.9992 - dice_coef_multi: 0.7674 - mean_acc: 0.9301 - auc: 1.0000
# Epoch 00088: loss did not improve from 0.00187
# 117/117 [==============================] - 17s 147ms/step - loss: 0.0020 - acc: 0.9992 - dice_coef_multi: 0.7674 - mean_acc: 0.9301 - auc: 1.0000
# Epoch 89/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0018 - acc: 0.9992 - dice_coef_multi: 0.7752 - mean_acc: 0.9355 - auc: 1.0000
# Epoch 00089: loss improved from 0.00187 to 0.00181, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 18s 151ms/step - loss: 0.0018 - acc: 0.9992 - dice_coef_multi: 0.7752 - mean_acc: 0.9355 - auc: 1.0000
# Epoch 90/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0019 - acc: 0.9992 - dice_coef_multi: 0.7771 - mean_acc: 0.9359 - auc: 1.0000
# Epoch 00090: loss did not improve from 0.00181
# 117/117 [==============================] - 17s 147ms/step - loss: 0.0019 - acc: 0.9992 - dice_coef_multi: 0.7771 - mean_acc: 0.9359 - auc: 1.0000
# Epoch 91/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0017 - acc: 0.9993 - dice_coef_multi: 0.7865 - mean_acc: 0.9417 - auc: 1.0000
# Epoch 00091: loss improved from 0.00181 to 0.00174, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 18s 151ms/step - loss: 0.0017 - acc: 0.9993 - dice_coef_multi: 0.7865 - mean_acc: 0.9417 - auc: 1.0000
# Epoch 92/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0018 - acc: 0.9993 - dice_coef_multi: 0.7848 - mean_acc: 0.9382 - auc: 1.0000
# Epoch 00092: loss did not improve from 0.00174
# 117/117 [==============================] - 17s 147ms/step - loss: 0.0018 - acc: 0.9993 - dice_coef_multi: 0.7848 - mean_acc: 0.9382 - auc: 1.0000
# Epoch 93/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0018 - acc: 0.9992 - dice_coef_multi: 0.7870 - mean_acc: 0.9367 - auc: 1.0000
# Epoch 00093: loss did not improve from 0.00174
# 117/117 [==============================] - 17s 147ms/step - loss: 0.0018 - acc: 0.9992 - dice_coef_multi: 0.7870 - mean_acc: 0.9367 - auc: 1.0000
# Epoch 94/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0017 - acc: 0.9993 - dice_coef_multi: 0.7895 - mean_acc: 0.9397 - auc: 1.0000
# Epoch 00094: loss improved from 0.00174 to 0.00174, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 17s 149ms/step - loss: 0.0017 - acc: 0.9993 - dice_coef_multi: 0.7895 - mean_acc: 0.9397 - auc: 1.0000
# Epoch 95/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0018 - acc: 0.9993 - dice_coef_multi: 0.7904 - mean_acc: 0.9461 - auc: 1.0000
# Epoch 00095: loss did not improve from 0.00174
# 117/117 [==============================] - 17s 146ms/step - loss: 0.0018 - acc: 0.9993 - dice_coef_multi: 0.7904 - mean_acc: 0.9461 - auc: 1.0000
# Epoch 96/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0017 - acc: 0.9993 - dice_coef_multi: 0.7957 - mean_acc: 0.9423 - auc: 1.0000
# Epoch 00096: loss improved from 0.00174 to 0.00172, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 17s 148ms/step - loss: 0.0017 - acc: 0.9993 - dice_coef_multi: 0.7957 - mean_acc: 0.9423 - auc: 1.0000
# Epoch 97/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0017 - acc: 0.9993 - dice_coef_multi: 0.7904 - mean_acc: 0.9475 - auc: 1.0000
# Epoch 00097: loss did not improve from 0.00172
# 117/117 [==============================] - 17s 147ms/step - loss: 0.0017 - acc: 0.9993 - dice_coef_multi: 0.7904 - mean_acc: 0.9475 - auc: 1.0000
# Epoch 98/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0017 - acc: 0.9993 - dice_coef_multi: 0.8037 - mean_acc: 0.9538 - auc: 1.0000
# Epoch 00098: loss improved from 0.00172 to 0.00165, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 17s 147ms/step - loss: 0.0017 - acc: 0.9993 - dice_coef_multi: 0.8037 - mean_acc: 0.9538 - auc: 1.0000
# Epoch 99/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0017 - acc: 0.9993 - dice_coef_multi: 0.8013 - mean_acc: 0.9356 - auc: 1.0000
# Epoch 00099: loss did not improve from 0.00165
# 117/117 [==============================] - 17s 146ms/step - loss: 0.0017 - acc: 0.9993 - dice_coef_multi: 0.8013 - mean_acc: 0.9356 - auc: 1.0000
# Epoch 100/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0017 - acc: 0.9993 - dice_coef_multi: 0.7986 - mean_acc: 0.9415 - auc: 1.0000
# Epoch 00100: loss did not improve from 0.00165
# 117/117 [==============================] - 17s 149ms/step - loss: 0.0017 - acc: 0.9993 - dice_coef_multi: 0.7986 - mean_acc: 0.9415 - auc: 1.0000
# Epoch 101/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0018 - acc: 0.9992 - dice_coef_multi: 0.7976 - mean_acc: 0.9356 - auc: 1.0000
# Epoch 00101: loss did not improve from 0.00165
# 117/117 [==============================] - 17s 146ms/step - loss: 0.0018 - acc: 0.9992 - dice_coef_multi: 0.7976 - mean_acc: 0.9356 - auc: 1.0000
# Epoch 102/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0017 - acc: 0.9993 - dice_coef_multi: 0.7906 - mean_acc: 0.9495 - auc: 1.0000
# Epoch 00102: loss did not improve from 0.00165
# 117/117 [==============================] - 17s 145ms/step - loss: 0.0017 - acc: 0.9993 - dice_coef_multi: 0.7906 - mean_acc: 0.9495 - auc: 1.0000
# Epoch 103/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0016 - acc: 0.9993 - dice_coef_multi: 0.8084 - mean_acc: 0.9451 - auc: 1.0000
# Epoch 00103: loss improved from 0.00165 to 0.00162, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 17s 148ms/step - loss: 0.0016 - acc: 0.9993 - dice_coef_multi: 0.8084 - mean_acc: 0.9451 - auc: 1.0000
# Epoch 104/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0016 - acc: 0.9993 - dice_coef_multi: 0.8010 - mean_acc: 0.9448 - auc: 1.0000
# Epoch 00104: loss improved from 0.00162 to 0.00159, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 17s 147ms/step - loss: 0.0016 - acc: 0.9993 - dice_coef_multi: 0.8010 - mean_acc: 0.9448 - auc: 1.0000
# Epoch 105/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0016 - acc: 0.9993 - dice_coef_multi: 0.8135 - mean_acc: 0.9560 - auc: 1.0000
# Epoch 00105: loss improved from 0.00159 to 0.00155, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 17s 149ms/step - loss: 0.0016 - acc: 0.9993 - dice_coef_multi: 0.8135 - mean_acc: 0.9560 - auc: 1.0000
# Epoch 106/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0016 - acc: 0.9993 - dice_coef_multi: 0.8125 - mean_acc: 0.9465 - auc: 1.0000
# Epoch 00106: loss did not improve from 0.00155
# 117/117 [==============================] - 17s 147ms/step - loss: 0.0016 - acc: 0.9993 - dice_coef_multi: 0.8125 - mean_acc: 0.9465 - auc: 1.0000
# Epoch 107/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0016 - acc: 0.9993 - dice_coef_multi: 0.8124 - mean_acc: 0.9531 - auc: 1.0000
# Epoch 00107: loss did not improve from 0.00155
# 117/117 [==============================] - 17s 146ms/step - loss: 0.0016 - acc: 0.9993 - dice_coef_multi: 0.8124 - mean_acc: 0.9531 - auc: 1.0000
# Epoch 108/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0016 - acc: 0.9993 - dice_coef_multi: 0.8104 - mean_acc: 0.9454 - auc: 1.0000
# Epoch 00108: loss did not improve from 0.00155
# 117/117 [==============================] - 17s 147ms/step - loss: 0.0016 - acc: 0.9993 - dice_coef_multi: 0.8104 - mean_acc: 0.9454 - auc: 1.0000
# Epoch 109/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0015 - acc: 0.9993 - dice_coef_multi: 0.8234 - mean_acc: 0.9516 - auc: 1.0000
# Epoch 00109: loss improved from 0.00155 to 0.00147, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_0.hdf5
# 117/117 [==============================] - 17s 148ms/step - loss: 0.0015 - acc: 0.9993 - dice_coef_multi: 0.8234 - mean_acc: 0.9516 - auc: 1.0000
# Epoch 110/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0015 - acc: 0.9994 - dice_coef_multi: 0.8181 - mean_acc: 0.9521 - auc: 1.0000
# Epoch 00110: loss did not improve from 0.00147
# ...
# Epoch 230/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0012 - acc: 0.9996 - dice_coef_multi: 0.7826 - mean_acc: 0.9784 - auc: 0.9865
# Epoch 00230: loss did not improve from 0.00098
# 117/117 [==============================] - 17s 144ms/step - loss: 0.0012 - acc: 0.9996 - dice_coef_multi: 0.7826 - mean_acc: 0.9784 - auc: 0.9865
# Epoch 231/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.
1000
# 117/117 [==============================] - ETA: 0s - loss: 9.6039e-04 - acc: 0.9997 - dice_coef_multi: 0.8010 - mean_acc: 0.9871 - auc: 0.9866
# Epoch 00249: loss did not improve from 0.00080
# 117/117 [==============================] - 17s 147ms/step - loss: 9.6039e-04 - acc: 0.9997 - dice_coef_multi: 0.8010 - mean_acc: 0.9871 - auc: 0.9866
# Epoch 250/1000
# 117/117 [==============================] - ETA: 0s - loss: 0.0010 - acc: 0.9997 - dice_coef_multi: 0.8081 - mean_acc: 0.9851 - auc: 0.9865
# Epoch 00250: loss did not improve from 0.00080
# 117/117 [==============================] - 17s 148ms/step - loss: 0.0010 - acc: 0.9997 - dice_coef_multi: 0.8081 - mean_acc: 0.9851 - auc: 0.9865
# Epoch 251/1000
# 117/117 [==============================] - ETA: 0s - loss: 8.2739e-04 - acc: 0.9998 - dice_coef_multi: 0.8153 - mean_acc: 0.9917 - auc: 0.9865
# Epoch 00251: loss did not improve from 0.00080
# 117/117 [==============================] - 17s 146ms/step - loss: 8.2739e-04 - acc: 0.9998 - dice_coef_multi: 0.8153 - mean_acc: 0.9917 - auc: 0.9865
# Epoch 252/1000
# 117/117 [==============================] - ETA: 0s - loss: 7.9527e-04 - acc: 0.9998 - dice_coef_multi: 0.8261 - mean_acc: 0.9897 - auc: 0.9867
# Epoch 00252: loss improved from 0.00080 to 0.00080, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_4.hdf5
# 117/117 [==============================] - 18s 153ms/step - loss: 7.9527e-04 - acc: 0.9998 - dice_coef_multi: 0.8261 - mean_acc: 0.9897 - auc: 0.9867
# Epoch 253/1000
# 117/117 [==============================] - ETA: 0s - loss: 7.5755e-04 - acc: 0.9998 - dice_coef_multi: 0.8223 - mean_acc: 0.9929 - auc: 0.9874
# Epoch 00253: loss improved from 0.00080 to 0.00076, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_4.hdf5
# 117/117 [==============================] - 17s 147ms/step - loss: 7.5755e-04 - acc: 0.9998 - dice_coef_multi: 0.8223 - mean_acc: 0.9929 - auc: 0.9874
# Epoch 254/1000
# 117/117 [==============================] - ETA: 0s - loss: 8.1486e-04 - acc: 0.9997 - dice_coef_multi: 0.8209 - mean_acc: 0.9854 - auc: 0.9874
# Epoch 00254: loss did not improve from 0.00076
# 117/117 [==============================] - 17s 146ms/step - loss: 8.1486e-04 - acc: 0.9997 - dice_coef_multi: 0.8209 - mean_acc: 0.9854 - auc: 0.9874
# Epoch 255/1000
# 117/117 [==============================] - ETA: 0s - loss: 8.1748e-04 - acc: 0.9998 - dice_coef_multi: 0.8276 - mean_acc: 0.9918 - auc: 0.9878
# Epoch 00255: loss did not improve from 0.00076
# 117/117 [==============================] - 17s 146ms/step - loss: 8.1748e-04 - acc: 0.9998 - dice_coef_multi: 0.8276 - mean_acc: 0.9918 - auc: 0.9878
# Epoch 256/1000
# 117/117 [==============================] - ETA: 0s - loss: 7.9161e-04 - acc: 0.9997 - dice_coef_multi: 0.8231 - mean_acc: 0.9890 - auc: 0.9880
# Epoch 00256: loss did not improve from 0.00076
# 117/117 [==============================] - 17s 146ms/step - loss: 7.9161e-04 - acc: 0.9997 - dice_coef_multi: 0.8231 - mean_acc: 0.9890 - auc: 0.9880
# Epoch 257/1000
# 117/117 [==============================] - ETA: 0s - loss: 9.5772e-04 - acc: 0.9997 - dice_coef_multi: 0.8186 - mean_acc: 0.9876 - auc: 0.9886
# Epoch 00257: loss did not improve from 0.00076
# 117/117 [==============================] - 17s 149ms/step - loss: 9.5772e-04 - acc: 0.9997 - dice_coef_multi: 0.8186 - mean_acc: 0.9876 - auc: 0.9886
# Epoch 258/1000
# 117/117 [==============================] - ETA: 0s - loss: 7.8918e-04 - acc: 0.9998 - dice_coef_multi: 0.8235 - mean_acc: 0.9888 - auc: 0.9888
# Epoch 00258: loss did not improve from 0.00076
# 117/117 [==============================] - 17s 147ms/step - loss: 7.8918e-04 - acc: 0.9998 - dice_coef_multi: 0.8235 - mean_acc: 0.9888 - auc: 0.9888
# Epoch 259/1000
# 117/117 [==============================] - ETA: 0s - loss: 7.6956e-04 - acc: 0.9998 - dice_coef_multi: 0.8302 - mean_acc: 0.9919 - auc: 0.9887
# Epoch 00259: loss did not improve from 0.00076
# 117/117 [==============================] - 17s 147ms/step - loss: 7.6956e-04 - acc: 0.9998 - dice_coef_multi: 0.8302 - mean_acc: 0.9919 - auc: 0.9887
# Epoch 260/1000
# 117/117 [==============================] - ETA: 0s - loss: 6.6528e-04 - acc: 0.9998 - dice_coef_multi: 0.8301 - mean_acc: 0.9907 - auc: 0.9890
# Epoch 00260: loss improved from 0.00076 to 0.00067, saving model to /media/nghia/Nguyen NghiaW/RRS-2021/20210322_RRS/RRS/3yrs_refined_data/seq_norm_8_nots/train_VAE_Kfold/model_VAE_KFold_4.hdf5
# 117/117 [==============================] - 17s 147ms/step - loss: 6.6528e-04 - acc: 0.9998 - dice_coef_multi: 0.8301 - mean_acc: 0.9907 - auc: 0.9890
# Epoch 261/1000
# 117/117 [==============================] - ETA: 0s - loss: 9.0448e-04 - acc: 0.9997 - dice_coef_multi: 0.8270 - mean_acc: 0.9886 - auc: 0.9892
# Epoch 00261: loss did not improve from 0.00067
# 117/117 [==============================] - 17s 148ms/step - loss: 9.0448e-04 - acc: 0.9997 - dice_coef_multi: 0.8270 - mean_acc: 0.9886 - auc: 0.9892
# Epoch 262/1000
# 117/117 [==============================] - ETA: 0s - loss: 7.0591e-04 - acc: 0.9998 - dice_coef_multi: 0.8312 - mean_acc: 0.9919 - auc: 0.9894
# Epoch 00262: loss did not improve from 0.00067
# 117/117 [==============================] - 18s 150ms/step - loss: 7.0591e-04 - acc: 0.9998 - dice_coef_multi: 0.8312 - mean_acc: 0.9919 - auc: 0.9894
# Epoch 263/1000
# 117/117 [==============================] - ETA: 0s - loss: 7.4907e-04 - acc: 0.9998 - dice_coef_multi: 0.8329 - mean_acc: 0.9917 - auc: 0.9897
# Epoch 00263: loss did not improve from 0.00067
# 117/117 [==============================] - 17s 148ms/step - loss: 7.4907e-04 - acc: 0.9998 - dice_coef_multi: 0.8329 - mean_acc: 0.9917 - auc: 0.9897
# Epoch 264/1000
# 117/117 [==============================] - ETA: 0s - loss: 8.6843e-04 - acc: 0.9997 - dice_coef_multi: 0.8318 - mean_acc: 0.9918 - auc: 0.9895
# Epoch 00264: loss did not improve from 0.00067
# 117/117 [==============================] - 17s 147ms/step - loss: 8.6843e-04 - acc: 0.9997 - dice_coef_multi: 0.8318 - mean_acc: 0.9918 - auc: 0.9895
# Epoch 265/1000
# 117/117 [==============================] - ETA: 0s - loss: 8.4403e-04 - acc: 0.9998 - dice_coef_multi: 0.8281 - mean_acc: 0.9900 - auc: 0.9901
# Epoch 00265: loss did not improve from 0.00067
# 117/117 [==============================] - 18s 153ms/step - loss: 8.4403e-04 - acc: 0.9998 - dice_coef_multi: 0.8281 - mean_acc: 0.9900 - auc: 0.9901
# Epoch 266/1000
# 117/117 [==============================] - ETA: 0s - loss: 8.3536e-04 - acc: 0.9997 - dice_coef_multi: 0.8293 - mean_acc: 0.9896 - auc: 0.9898
# Epoch 00266: loss did not improve from 0.00067
# 117/117 [==============================] - 17s 149ms/step - loss: 8.3536e-04 - acc: 0.9997 - dice_coef_multi: 0.8293 - mean_acc: 0.9896 - auc: 0.9898
# Epoch 267/1000
# 117/117 [==============================] - ETA: 0s - loss: 7.9603e-04 - acc: 0.9998 - dice_coef_multi: 0.8298 - mean_acc: 0.9942 - auc: 0.9898
# Epoch 00267: loss did not improve from 0.00067
# 117/117 [==============================] - 18s 153ms/step - loss: 7.9603e-04 - acc: 0.9998 - dice_coef_multi: 0.8298 - mean_acc: 0.9942 - auc: 0.9898
# Epoch 268/1000
# 117/117 [==============================] - ETA: 0s - loss: 9.2286e-04 - acc: 0.9998 - dice_coef_multi: 0.8308 - mean_acc: 0.9926 - auc: 0.9895
# Epoch 00268: loss did not improve from 0.00067
# 117/117 [==============================] - 18s 154ms/step - loss: 9.2286e-04 - acc: 0.9998 - dice_coef_multi: 0.8308 - mean_acc: 0.9926 - auc: 0.9895
# Epoch 269/1000
# 117/117 [==============================] - ETA: 0s - loss: 8.4052e-04 - acc: 0.9998 - dice_coef_multi: 0.8230 - mean_acc: 0.9932 - auc: 0.9900
# Epoch 00269: loss did not improve from 0.00067
# 117/117 [==============================] - 17s 147ms/step - loss: 8.4052e-04 - acc: 0.9998 - dice_coef_multi: 0.8230 - mean_acc: 0.9932 - auc: 0.9900
# Epoch 270/1000
# 117/117 [==============================] - ETA: 0s - loss: 8.6985e-04 - acc: 0.9997 - dice_coef_multi: 0.8283 - mean_acc: 0.9883 - auc: 0.9900
# Epoch 00270: loss did not improve from 0.00067
# 117/117 [==============================] - 17s 147ms/step - loss: 8.6985e-04 - acc: 0.9997 - dice_coef_multi: 0.8283 - mean_acc: 0.9883 - auc: 0.9900
# TestFold 4 Mean-Acc: 0.963692527612867
# [[59524     9]
#  [   15   192]]
#
# TestFold 4 Mean-Auc: 0.96369
# TestFold 4 AUC proba: 0.995348984783416
# TestFold 4 Mean-PRC: 0.93804
# TestFold 4 AVG-PRC: 0.8862558468628314

# %%
tf.keras.backend.clear_session()

#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import roc_auc_score, precision_recall_curve, auc, roc_curve

kf = KFold(n_splits=5, random_state=seed, shuffle=True)
stra_kf = StratifiedKFold(n_splits=5, random_state=seed, shuffle=True)

result_info = {}
count = 0
for train_index, test_index in kf.split(x_train, y_train):
    #tf.keras.backend.clear_session()
    x_train1, x_test1 = x_train[train_index], x_train[test_index]
    y_train1, y_test1 = y_train[train_index], y_train[test_index]
    print('train:',np.unique(y_train1, return_counts = True))
    print('test:',np.unique(y_test1, return_counts = True))
# Out:
# train: (array([0, 1]), array([238161,    799]))
# test: (array([0, 1]), array([59533,   208]))
# train: (array([0, 1]), array([238147,    814]))
# test: (array([0, 1]), array([59547,   193]))
# train: (array([0, 1]), array([238143,    818]))
# test: (array([0, 1]), array([59551,   189]))
# train: (array([0, 1]), array([238164,    797]))
# test: (array([0, 1]), array([59530,   210]))
# train: (array([0, 1]), array([238161,    800]))
# test: (array([0, 1]), array([59533,   207]))
